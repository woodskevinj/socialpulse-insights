# %%
import sys
from pathlib import Path

project_root = Path().resolve().parents[0]
sys.path.append(str(project_root))
from src.data_loader import load_sentiment140

# %%
df = load_sentiment140()
df.head()
# Out:
#                                                 text     label  \
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...  negative
# 1  is upset that he can't update his Facebook by ...  negative
# 2  @Kenichan I dived many times for the ball. Man...  negative
# 3    my whole body feels itchy and like its on fire   negative
# 4  @nationwideclass no, it's not behaving at all....  negative
#
#                            date             user         ids
# 0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_  1467810369
# 1  Mon Apr 06 22:19:49 PDT 2009    scotthamilton  1467810672
# 2  Mon Apr 06 22:19:53 PDT 2009         mattycus  1467810917
# 3  Mon Apr 06 22:19:57 PDT 2009          ElleCTF  1467811184
# 4  Mon Apr 06 22:19:57 PDT 2009           Karoli  1467811193

# %%
from src.preprocessing import apply_cleaning
from src.entity_tagger import tag_entities

# %%
df_clean = apply_cleaning(df)
df_tagged = tag_entities(df_clean, text_col="text_clean")

# %%
df_tagged.head()
# Out:
#                                                 text     label  \
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...  negative
# 1  is upset that he can't update his Facebook by ...  negative
# 2  @Kenichan I dived many times for the ball. Man...  negative
# 3    my whole body feels itchy and like its on fire   negative
# 4  @nationwideclass no, it's not behaving at all....  negative
#
#                            date             user         ids  \
# 0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_  1467810369
# 1  Mon Apr 06 22:19:49 PDT 2009    scotthamilton  1467810672
# 2  Mon Apr 06 22:19:53 PDT 2009         mattycus  1467810917
# 3  Mon Apr 06 22:19:57 PDT 2009          ElleCTF  1467811184
# 4  Mon Apr 06 22:19:57 PDT 2009           Karoli  1467811193
#
#                                           text_clean entities  \
# 0  - awww, that's a bummer. you shoulda got david...       []
# 1  is upset that he can't update his facebook by ...       []
# ...

# %%
df_tagged["primary_entity_name"].value_counts().head(20)
# Out:
# primary_entity_name
# beyonce knowles-carter    325
# sean carter                52
# electric vehicles          13
# bitcoin                     3
# Name: count, dtype: int64

# %%
# Out:
# primary_entity_name
# beyonce knowles-carter    325
# sean carter                52
# electric vehicles          13
# bitcoin                     3
# Name: count, dtype: int64
